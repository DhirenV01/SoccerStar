# %%
import pandas as pd

import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch

from fontTools.ttLib import TTCollection

# %%
df = pd.read_csv('/Users/dhirenvazirani/mbappe/mbappe_real_madrid_data.csv')

# %%
df.head()
# Out:
#        id  minute       result      X      Y        xG                player  \
# 0  585517      24  MissedShots  0.952  0.576  0.141936  Kylian Mbappe-Lottin
# 1  585525      61    SavedShot  0.881  0.706  0.034307  Kylian Mbappe-Lottin
# 2  585528      69    SavedShot  0.939  0.671  0.062559  Kylian Mbappe-Lottin
# 3  585529      70  MissedShots  0.856  0.579  0.026641  Kylian Mbappe-Lottin
# 4  586749       8    SavedShot  0.893  0.687  0.054954  Kylian Mbappe-Lottin
#
#   h_a  player_id   situation  season   shotType  match_id       h_team  \
# 0   a       3423    OpenPlay    2024  RightFoot     26989     Mallorca
# 1   a       3423    OpenPlay    2024  RightFoot     26989     Mallorca
# 2   a       3423    OpenPlay    2024   LeftFoot     26989     Mallorca
# 3   a       3423  FromCorner    2024  RightFoot     26989     Mallorca
# 4   h       3423    OpenPlay    2024   LeftFoot     26998  Real Madrid
#
#             a_team  h_goals  a_goals                 date  player_assisted  \
# 0      Real Madrid        1        1  2024-08-18 19:30:00  Vinícius Júnior
# 1      Real Madrid        1        1  2024-08-18 19:30:00  Jude Bellingham
# 2      Real Madrid        1        1  2024-08-18 19:30:00              NaN
# 3      Real Madrid        1        1  2024-08-18 19:30:00              NaN
# 4  Real Valladolid        3        0  2024-08-25 15:00:00  Antonio Rüdiger
#
#   lastAction
# 0       Pass
# 1       Pass
# 2        NaN
# 3     Aerial
# 4    Chipped

# %%
df['X'] = df['X'] * 100
df['Y'] = df['Y'] * 100

# %%
total_shots = df.shape[0]
total_goals = df[df['result'] == 'Goal'].shape[0]
total_xG = df['xG'].sum()
xG_per_shot = total_xG / total_shots
points_average_distance = df['X'].mean()
actual_average_distance = 120 - (df['X'] * 1.2).mean()
